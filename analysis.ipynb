# %% [markdown]
# **Analyse der erstellten Daten:**

# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %%
RESULT_FILE = "results/results_direct_gpt-5.1.json"

with open(RESULT_FILE, "r") as f:
    data = json.load(f)

df = pd.DataFrame(data)

print("Number of tasks:", len(df))
df.head()
# Out:
# Number of tasks: 5
#   id task_type                                        question ground_truth  \
# 0  1      None   Count the vowels in the string: dgfdsfhuipoai            5
# 1  2      None     Count the vowels in the string: oihjsahsaud            5
# 2  3      None     Count the vowels in the string: aufnbejtkfi            4
# 3  4      None   Count the vowels in the string: hkhgfdhybnijg            1
# 4  5      None  Count the Consonants in the string: hgrwopjuia            6
#
#      model strategy raw_output parsed_prediction  correct   latency
# 0  gpt-5.1   direct          5                 5     True  1.962648
# 1  gpt-5.1   direct          6                 6    False  1.649022
# 2  gpt-5.1   direct          3                 3    False  1.785552
# 3  gpt-5.1   direct          1                 1     True  1.791181
# 4  gpt-5.1   direct          7                 7    False  1.431785

# %%
accuracy = df["correct"].mean()

print("Overall Accuracy:", round(accuracy * 100, 2), "%")
# Out:
# Overall Accuracy: 40.0 %

# %%
strategy_acc = df.groupby("strategy")["correct"].mean().reset_index()

strategy_acc
# Out:
#   strategy  correct
# 0   direct      0.4
